# %%
import pandas as pd
import numpy as np
import re
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge, RidgeCV, Lasso
from sklearn.preprocessing import StandardScaler,LabelEncoder

# %%
housing =  pd.read_csv("BHP.csv")

# %%
housing_df = housing.copy()

# %%
housing_df.dropna(subset=["size","bath","location"],inplace=True)

# %%
housing_df.loc[housing_df["availability"]!="Ready To Move","availability"] = "Not Ready To Move"
housing_df.loc[housing_df["balcony"].isna(),"balcony"] = 0
housing.society.fillna("No Society",inplace=True)

# %%
housing_df = housing_df.astype({"area_type":"str","availability":"str","location":"str","size":"str","society":"str","total_sqft":"str","bath":"int","balcony":"int"})

# %%
housing_df = housing_df[~housing_df["total_sqft"].str.contains("[a-zA-Z]")]

# %%
total_sqft = []

for i in housing_df["total_sqft"]:
    if(len(i.split("-"))>1):
        total_sqft.append((float(i.split("-")[0])+float(i.split("-")[1]))/2)
    else:
        total_sqft.append(float(i))

housing_df["total_sqft"] = total_sqft

# %%
housing_df
# Out:
#        area_type  availability  location  size  society  total_sqft  bath  \
# 0              3             0       416    13      456      1056.0     2
# 1              2             1       314    19     2417      2600.0     5
# 2              0             1      1173    16     2665      1440.0     2
# 3              3             1       753    16     2166      1521.0     3
# 4              3             1       712    13     2665      1200.0     2
# ...          ...           ...       ...   ...      ...         ...   ...
# 13315          0             1      1246    22      206      3453.0     4
# 13316          3             1       998    18     2665      3600.0     5
# 13317          0             1       966    13     1206      1141.0     2
# 13318          3             0       901    18     2185      4689.0     4
# 13319          3             1       393     0     2665       550.0     1
#
#        balcony   price
# 0            1   39.07
# 1            3  120.00
# 2            3   62.00
# 3            1   95.00
# 4            1   51.00
# ...        ...     ...
# 13315        0  231.00
# 13316        0  400.00
# 13317        1   60.00
# 13318        1  488.00
# 13319        1   17.00
#
# [13200 rows x 9 columns]

# %%
le = LabelEncoder()
area_type = le.fit_transform( housing_df["area_type"])
housing_df["area_type"] = area_type
area_type = le.fit_transform( housing_df["availability"])
housing_df["availability"] = area_type
area_type = le.fit_transform( housing_df["location"])
housing_df["location"] = area_type
area_type = le.fit_transform( housing_df["size"])
housing_df["size"] = area_type
area_type = le.fit_transform( housing_df["society"])
housing_df["society"] = area_type

# %%
X = housing_df.iloc[:,[0,1,2,3,4,5,6,7]]
y = housing_df.iloc[:,[8]]

# %%
xtrain, xtest, ytrain, ytest = train_test_split(
    X, y, test_size=0.25, random_state=0)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(xtrain)
X_test = scaler.transform(xtest)

# %%
X_train
# Out:
# array([[ 0.62004487, -1.98125544,  1.58567706, ..., -0.71357072,
#         -1.24345109, -1.76318785],
#        [ 0.62004487,  0.50473047, -1.31068099, ..., -0.41824953,
#         -0.50847194, -0.60118814],
#        [-0.25624981,  0.50473047, -1.05786795, ...,  0.03250386,
#          0.96148636, -0.60118814],
#        ...,
#        [-2.00883917,  0.50473047,  1.0195957 , ...,  1.92955391,
#          0.96148636,  0.56081158],
#        [ 0.62004487,  0.50473047,  1.04707537, ...,  0.18638174,
#          0.22650721,  1.7228113 ],
#        [-0.25624981,  0.50473047, -1.20625821, ..., -0.68248428,
#          0.96148636, -0.60118814]])

# %%
lr = LinearRegression()
lr.fit(X_train,ytrain)
# Out:
# LinearRegression()

# %%
predictions = []
for i in X_test:
    predictions.append(lr.predict([i])[0])

# %%
predictions
# Out:
# [array([104.99796311]),
#  array([142.52243898]),
#  array([163.20414912]),
#  array([58.78145212]),
#  array([38.44771877]),
#  array([73.61090957]),
#  array([262.03473131]),
#  array([133.10354955]),
#  array([120.54832035]),
#  array([105.66547331]),
#  array([6.61103595]),
#  array([6.50625538]),
#  array([61.65965588]),
#  array([86.89966056]),
#  array([70.26857873]),
#  array([132.8343517]),
#  array([167.66099418]),
#  array([61.79787083]),
#  array([14.03058454]),
#  array([118.48096658]),
#  array([111.41564117]),
#  array([73.57435105]),
#  array([318.22868264]),
#  array([65.38399501]),
#  array([79.44415542]),
#  array([207.56467889]),
#  array([116.86221156]),
#  array([65.28078331]),
#  array([96.33704953]),
#  array([296.07881818]),
#  array([80.47137335]),
#  array([89.60198267]),
#  array([72.58020832]),
#  array([180.24886122]),
#  array([169.62231283]),
#  array([77.88312219]),
#  array([75.34434249]),
#  array([60.96983283]),
#  array([80.55716916]),
#  array([72.24260827]),
#  array([4.94981021]),
#  array([110.22415631]),
#  array([76.90517704]),
#  array([78.0035245]),
#  array([196.32832131]),
#  array([87.58298553]),
#  array([237.58885168]),
#  array([69.83632314]),
#  array([107.8551922]),
#  array([65.52376074]),
#  array([173.31207219]),
#  array([175.52679019]),
#  array([125.78421875]),
#  array([177.312577]),
#  array([195.41438937]),
#  array([155.24358632]),
#  array([84.345918]),
#  array([73.58841422]),
#  array([74.35599855]),
#  array([63.23098333]),
#  array([65.60824542]),
#  array([71.20821067]),
#  array([138.66612629]),
#  array([329.3225184]),
#  array([73.80619713]),
#  array([67.95791823]),
#  array([74.75114182]),
#  array([138.68261751]),
#  array([65.70242598]),
#  array([138.29151061]),
#  array([21.83148807]),
#  array([65.94054314]),
#  array([111.31478286]),
#  array([351.86116068]),
#  array([-0.79385296]),
#  array([64.65206886]),
#  array([78.19614155]),
#  array([340.74051148]),
#  array([57.23235106]),
#  array([211.7974727]),
#  array([131.66988304]),
#  array([121.0247504]),
#  array([78.58002731]),
#  array([79.80119612]),
#  array([114.37141361]),
#  array([79.01526129]),
#  array([63.93205494]),
#  array([347.48964774]),
#  array([128.6855632]),
#  array([10.0016661]),
#  array([71.77581104]),
#  array([236.45145625]),
#  array([61.08508582]),
#  array([67.21498144]),
#  array([137.31685638]),
#  array([66.75546289]),
#  array([86.88793249]),
#  array([70.77768528]),
#  array([110.45434776]),
#  array([102.72302553]),
#  array([159.42374666]),
#  array([105.17810577]),
#  array([76.12601194]),
#  array([177.01581166]),
#  array([101.23768302]),
#  array([75.62849654]),
#  array([62.21869242]),
#  array([404.63140817]),
#  array([76.59344174]),
#  array([95.32536178]),
#  array([69.85516078]),
#  array([45.28043854]),
#  array([262.46265302]),
#  array([93.38293741]),
#  array([94.15406867]),
#  array([333.67511677]),
#  array([138.18018138]),
#  array([220.95735096]),
#  array([247.35323367]),
#  array([126.45741103]),
#  array([117.19175069]),
#  array([74.03416166]),
#  array([57.76613882]),
#  array([126.8827571]),
#  array([69.20521844]),
#  array([58.35211148]),
#  array([2.21703478]),
#  array([66.75546289]),
#  array([74.19032858]),
#  array([72.49193861]),
#  array([122.97779069]),
#  array([192.85422005]),
#  array([68.47904725]),
#  array([103.35313277]),
#  array([69.52796786]),
#  array([70.30491451]),
#  array([204.6734533]),
#  array([105.66408146]),
#  array([225.30141804]),
#  array([90.41269737]),
#  array([69.11361022]),
#  array([84.65178455]),
#  array([86.37074266]),
#  array([113.34690713]),
#  array([70.43182553]),
#  array([76.91191709]),
#  array([269.75926896]),
#  array([64.72438325]),
#  array([142.56229728]),
#  array([133.10471826]),
#  array([159.48325493]),
#  array([64.59670192]),
#  array([122.75465441]),
#  array([4.46273035]),
#  array([144.15131677]),
#  array([126.60477705]),
#  array([129.12119543]),
#  array([181.15168129]),
#  array([78.27153566]),
#  array([513.86031306]),
#  array([148.20083758]),
#  array([76.65765086]),
#  array([65.84925244]),
#  array([1047.94884177]),
#  array([62.58880334]),
#  array([122.12378005]),
#  array([81.18308043]),
#  array([74.67342404]),
#  array([116.35345083]),
#  array([70.09089845]),
#  array([85.70560838]),
#  array([111.21919587]),
#  array([394.9183723]),
#  array([92.12054659]),
#  array([108.22612034]),
#  array([78.91545094]),
#  array([69.8474749]),
#  array([70.98380589]),
#  array([154.26037189]),
#  array([349.35167918]),
#  array([125.36632887]),
#  array([184.85714462]),
#  array([46.19827964]),
#  array([62.02006189]),
#  array([226.82630198]),
#  array([69.90707425]),
#  array([72.08523165]),
#  array([100.65926421]),
#  array([10.04615607]),
#  array([108.83768743]),
#  array([59.49597637]),
#  array([66.74555188]),
#  array([138.98105482]),
#  array([119.51009147]),
#  array([71.16320487]),
#  array([71.35901338]),
#  array([119.47068667]),
#  array([229.15847507]),
#  array([74.9826235]),
#  array([109.01264314]),
#  array([291.93184253]),
#  array([74.24608514]),
#  array([145.02568457]),
#  array([72.55537468]),
#  array([361.03024603]),
#  array([66.96426629]),
#  array([128.51838108]),
#  array([132.91318507]),
#  array([148.2433164]),
#  array([87.56582473]),
#  array([17.00134239]),
#  array([53.97004354]),
#  array([91.29944859]),
#  array([67.68503809]),
#  array([114.17121673]),
#  array([89.05867046]),
#  array([250.15254425]),
#  array([119.04647125]),
#  array([225.31507331]),
#  array([122.1073087]),
#  array([76.65560508]),
#  array([116.69989036]),
#  array([166.57468602]),
#  array([66.28148395]),
#  array([67.99934792]),
#  array([114.35010746]),
#  array([63.58299328]),
#  array([55.0049351]),
#  array([110.5213201]),
#  array([72.27921943]),
#  array([55.93316185]),
#  array([71.63905898]),
#  array([181.51345802]),
#  array([246.82368208]),
#  array([130.33510516]),
#  array([64.98160242]),
#  array([51.89063707]),
#  array([73.79992311]),
#  array([165.38541816]),
#  array([75.07074958]),
#  array([187.62880696]),
#  array([71.25405483]),
#  array([57.17103587]),
#  array([53.97004354]),
#  array([126.7362824]),
#  array([12.18104974]),
#  array([207.1996466]),
#  array([66.43312744]),
#  array([81.30040435]),
#  array([53.36009679]),
#  array([179.6848253]),
#  array([141.28514651]),
#  array([137.34357268]),
#  array([130.43405647]),
#  array([-0.79385296]),
#  array([72.56462373]),
#  array([61.1509338]),
#  array([81.76320816]),
#  array([380.65208148]),
#  array([54.58283496]),
#  array([73.18919699]),
#  array([73.06336129]),
#  array([368.64397835]),
#  array([76.05669842]),
#  array([71.304703]),
#  array([62.34611915]),
#  array([80.31296973]),
#  array([137.23511702]),
#  array([77.3780611]),
#  array([474.88570761]),
#  array([143.82593163]),
#  array([65.91171552]),
#  array([15.27993598]),
#  array([310.41711558]),
#  array([253.00123792]),
#  array([205.07064858]),
#  array([133.11101188]),
#  array([63.27348964]),
#  array([36.67192363]),
#  array([77.48963787]),
#  array([58.49502284]),
#  array([23.33268839]),
#  array([69.75419628]),
#  array([71.58717644]),
#  array([60.79648034]),
#  array([220.4831405]),
#  array([244.60722202]),
#  array([111.38341953]),
#  array([261.74168566]),
#  array([66.75546289]),
#  array([64.41951722]),
#  array([111.24490082]),
#  array([80.40590057]),
#  array([132.77122505]),
#  array([128.08785181]),
#  array([69.95084818]),
#  array([84.44153211]),
#  array([74.63876577]),
#  array([283.30129682]),
#  array([78.56615129]),
#  array([129.82727755]),
#  array([68.99904995]),
#  array([113.17758594]),
#  array([67.68594056]),
#  array([56.31218418]),
#  array([73.30488806]),
#  array([53.29617509]),
#  array([76.77137789]),
#  array([343.3650966]),
#  array([180.91168084]),
#  array([63.77204263]),
#  array([59.88135458]),
#  array([78.08193888]),
#  array([81.26914653]),
#  array([80.61485767]),
#  array([122.45663526]),
#  array([164.45883243]),
#  array([117.33004043]),
#  array([88.57494435]),
#  array([66.69397573]),
#  array([64.98759225]),
#  array([106.20297201]),
#  array([204.68495404]),
#  array([69.91750049]),
#  array([62.75867938]),
#  array([40.6122568]),
#  array([135.51051368]),
#  array([60.99916662]),
#  array([172.9941405]),
#  array([226.05873768]),
#  array([82.40976525]),
#  array([17.16550464]),
#  array([138.91375192]),
#  array([69.01601813]),
#  array([168.29557718]),
#  array([127.4256973]),
#  array([83.61709564]),
#  array([211.93969417]),
#  array([81.656259]),
#  array([111.61388647]),
#  array([76.72545165]),
#  array([287.53979611]),
#  array([132.64218704]),
#  array([363.03159296]),
#  array([67.05091906]),
#  array([463.0053936]),
#  array([63.56352675]),
#  array([122.80740164]),
#  array([63.43704683]),
#  array([71.2546042]),
#  array([84.88512175]),
#  array([70.59014582]),
#  array([207.67163457]),
#  array([162.37703304]),
#  array([112.87107886]),
#  array([81.7657061]),
#  array([122.86092235]),
#  array([152.30008513]),
#  array([106.03882143]),
#  array([285.96646094]),
#  array([65.78392815]),
#  array([135.80931362]),
#  array([80.20672203]),
#  array([72.96585047]),
#  array([87.56140389]),
#  array([59.71168251]),
#  array([79.22458952]),
#  array([27.01520297]),
#  array([218.84719433]),
#  array([70.26452443]),
#  array([74.19032858]),
#  array([72.90478548]),
#  array([70.16769925]),
#  array([284.06701326]),
#  array([123.54042686]),
#  array([288.44053061]),
#  array([100.22798053]),
#  array([201.28829578]),
#  array([62.12513982]),
#  array([70.36677789]),
#  array([71.17464178]),
#  array([127.84890807]),
#  array([63.58299328]),
#  array([18.720013]),
#  array([67.01559469]),
#  array([179.3294727]),
#  array([77.92275611]),
#  array([195.4851373]),
#  array([75.11595358]),
#  array([86.66008624]),
#  array([69.78632714]),
#  array([62.78461121]),
#  array([78.3437412]),
#  array([222.92148013]),
#  array([179.4752911]),
#  array([283.79291167]),
#  array([55.59265489]),
#  array([58.93197197]),
#  array([62.66730123]),
#  array([87.41608356]),
#  array([177.99902867]),
#  array([190.89961361]),
#  array([70.13716732]),
#  array([187.88319427]),
#  array([116.18297321]),
#  array([60.34641094]),
#  array([55.37826383]),
#  array([62.87207899]),
#  array([63.81730149]),
#  array([171.3865699]),
#  array([120.07772743]),
#  array([83.62167634]),
#  array([255.38968803]),
#  array([136.71903749]),
#  array([149.05684911]),
#  array([139.84109455]),
#  array([182.19473083]),
#  array([74.98363592]),
#  array([74.35966396]),
#  array([331.23309303]),
#  array([70.71022413]),
#  array([8.0130513]),
#  array([138.05731577]),
#  array([85.77654639]),
#  array([139.64421105]),
#  array([81.21722602]),
#  array([62.78705869]),
#  array([8.80175802]),
#  array([356.12676857]),
#  array([61.93415663]),
#  array([143.21263772]),
#  array([205.37466398]),
#  array([122.75421317]),
#  array([58.01899687]),
#  array([70.40551666]),
#  array([111.08086262]),
#  array([74.98363592]),
#  array([70.16745436]),
#  array([93.71080558]),
#  array([68.63857526]),
#  array([78.97463326]),
#  array([91.21072916]),
#  array([107.57291103]),
#  array([77.97134581]),
#  array([190.07957757]),
#  array([49.92425558]),
#  array([104.76626416]),
#  array([35.80392614]),
#  array([62.91520977]),
#  array([379.93159563]),
#  array([108.93431645]),
#  array([115.01843415]),
#  array([81.42106382]),
#  array([332.38480184]),
#  array([78.20503946]),
#  array([71.43594573]),
#  array([128.83684601]),
#  array([69.11187964]),
#  array([17.81464558]),
#  array([69.33090443]),
#  array([66.80993734]),
#  array([129.06962137]),
#  array([64.34725711]),
#  array([81.51777845]),
#  array([93.59813509]),
#  array([144.56522502]),
#  array([137.79008417]),
#  array([115.83049467]),
#  array([121.14603409]),
#  array([52.72707422]),
#  array([198.2658062]),
#  array([73.92066593]),
#  array([195.21675867]),
#  array([7.07013302]),
#  array([120.30421492]),
#  array([172.75302352]),
#  array([58.48855045]),
#  array([71.0704894]),
#  array([147.62169831]),
#  array([10.57003245]),
#  array([66.08934718]),
#  array([121.74469024]),
#  array([66.98056817]),
#  array([68.7663465]),
#  array([58.70566976]),
#  array([88.68862095]),
#  array([178.89303892]),
#  array([73.56248845]),
#  array([5.86852117]),
#  array([246.10571849]),
#  array([63.9082274]),
#  array([164.20025018]),
#  array([81.78175376]),
#  array([128.09900513]),
#  array([7.57852859]),
#  array([112.90907329]),
#  array([132.00891613]),
#  array([178.46952481]),
#  array([83.27405004]),
#  array([59.63873523]),
#  array([127.80151488]),
#  array([70.47703291]),
#  array([117.09446161]),
#  array([64.96200363]),
#  array([16.94811061]),
#  array([116.28625649]),
#  array([159.08181]),
#  array([296.52589713]),
#  array([330.85735636]),
#  array([4.750868]),
#  array([61.52816394]),
#  array([46.9657233]),
#  array([387.33766013]),
#  array([59.69660666]),
#  array([27.04009686]),
#  array([74.98363592]),
#  array([120.34156649]),
#  array([80.52713364]),
#  array([210.40602053]),
#  array([72.35988425]),
#  array([60.54055419]),
#  array([82.19630449]),
#  array([73.70747887]),
#  array([85.90957261]),
#  array([66.80993734]),
#  array([154.12388716]),
#  array([315.48974777]),
#  array([95.07723811]),
#  array([91.875296]),
#  array([121.65619243]),
#  array([129.16737297]),
#  array([68.85769405]),
#  array([118.89651808]),
#  array([62.52924223]),
#  array([237.12155012]),
#  array([106.15023786]),
#  array([229.19250873]),
#  array([67.63924419]),
#  array([65.57974555]),
#  array([46.90073108]),
#  array([7.56286569]),
#  array([57.5303891]),
#  array([100.56919065]),
#  array([69.38405317]),
#  array([114.7316103]),
#  array([66.74368745]),
#  array([71.44843361]),
#  array([87.12927511]),
#  array([149.0400399]),
#  array([71.57878639]),
#  array([67.99353967]),
#  array([59.4578557]),
#  array([253.19906799]),
#  array([61.4871874]),
#  array([86.42947621]),
#  array([163.39363297]),
#  array([112.15732924]),
#  array([42.22612047]),
#  array([65.365978]),
#  array([81.31052173]),
#  array([150.01637675]),
#  array([134.4790443]),
#  array([147.40001141]),
#  array([76.04704177]),
#  array([115.36218784]),
#  array([136.5035243]),
#  array([131.74199424]),
#  array([76.55420264]),
#  array([71.19466511]),
#  array([90.97547925]),
#  array([139.99219461]),
#  array([61.82739579]),
#  array([63.38337047]),
#  array([70.75372312]),
#  array([68.98783052]),
#  array([50.07078431]),
#  array([66.93833024]),
#  array([79.09956811]),
#  array([68.44791554]),
#  array([196.13002715]),
#  array([62.7489776]),
#  array([74.65533077]),
#  array([66.75953699]),
#  array([92.07315462]),
#  array([109.36174687]),
#  array([95.87866432]),
#  array([93.50647263]),
#  array([99.23828392]),
#  array([52.79871149]),
#  array([251.18906935]),
#  array([167.08387594]),
#  array([77.08502369]),
#  array([11.58921659]),
#  array([65.33713554]),
#  array([78.9419784]),
#  array([82.94674032]),
#  array([73.98016179]),
#  array([126.80780647]),
#  array([70.07386192]),
#  array([80.31661358]),
#  array([124.5500377]),
#  array([223.81935429]),
#  array([127.52583063]),
#  array([45.13788025]),
#  array([64.68889198]),
#  array([82.90087706]),
#  array([118.12903887]),
#  array([175.74084412]),
#  array([70.15495126]),
#  array([64.58301885]),
#  array([65.04793301]),
#  array([76.87305976]),
#  array([-2.19686619]),
#  array([320.78558332]),
#  array([213.44073048]),
#  array([148.54996517]),
#  array([86.23665216]),
#  array([65.81478477]),
#  array([65.54590332]),
#  array([107.87645571]),
#  array([120.63333604]),
#  array([62.06909935]),
#  array([67.76348735]),
#  array([65.91024712]),
#  array([113.80890597]),
#  array([161.31329875]),
#  array([123.85588785]),
#  array([20.08422478]),
#  array([69.0717414]),
#  array([76.41957936]),
#  array([59.97155321]),
#  array([133.28407542]),
#  array([754.13016954]),
#  array([98.29580147]),
#  array([233.60468974]),
#  array([107.46568482]),
#  array([65.91024712]),
#  array([74.45074222]),
#  array([312.7630388]),
#  array([63.85144003]),
#  array([332.42378307]),
#  array([79.9465387]),
#  array([113.12661352]),
#  array([88.56822141]),
#  array([154.21129856]),
#  array([78.73954638]),
#  array([84.35700662]),
#  array([149.39195359]),
#  array([161.31329875]),
#  array([227.91057703]),
#  array([112.0398803]),
#  array([65.72062704]),
#  array([61.30446967]),
#  array([75.89742352]),
#  array([109.59140146]),
#  array([85.63806866]),
#  array([72.83743946]),
#  array([120.84546611]),
#  array([84.69353866]),
#  array([20.95088205]),
#  array([57.65844891]),
#  array([59.21543151]),
#  array([179.67769464]),
#  array([122.73349154]),
#  array([53.98985538]),
#  array([342.00186065]),
#  array([71.02018812]),
#  array([63.94511388]),
#  array([122.383382]),
#  array([64.49368963]),
#  array([69.94197054]),
#  array([127.51779477]),
#  array([88.01021142]),
#  array([136.38732595]),
#  array([228.59751905]),
#  array([69.38327259]),
#  array([83.25361883]),
#  array([182.50267139]),
#  array([133.53033267]),
#  array([22.11062785]),
#  array([172.01324548]),
#  array([61.54084607]),
#  array([61.52515416]),
#  array([207.74799057]),
#  array([189.0260576]),
#  array([163.84723953]),
#  array([73.6041455]),
#  array([62.17016068]),
#  array([40.58670651]),
#  array([62.66728761]),
#  array([70.66842349]),
#  array([116.91511606]),
#  array([80.18441545]),
#  array([85.77654639]),
#  array([73.20436991]),
#  array([164.33647383]),
#  array([123.41228986]),
#  array([160.14299215]),
#  array([69.11519953]),
#  array([112.40558045]),
#  array([72.35586922]),
#  array([129.58813085]),
#  array([186.73676011]),
#  array([272.26242412]),
#  array([176.19288837]),
#  array([136.03218353]),
#  array([232.19707809]),
#  array([73.28346829]),
#  array([85.56227227]),
#  array([74.61072937]),
#  array([116.39556939]),
#  array([108.81087921]),
#  array([64.14064617]),
#  array([72.46747388]),
#  array([56.64765641]),
#  array([82.52854703]),
#  array([65.81979046]),
#  array([7.57852859]),
#  array([158.41551623]),
#  array([68.93122106]),
#  array([116.44527325]),
#  array([49.80973135]),
#  array([7.32123026]),
#  array([273.11767782]),
#  array([61.67865067]),
#  array([85.88617011]),
#  array([134.09588429]),
#  array([174.06723671]),
#  array([65.01726877]),
#  array([122.96897445]),
#  array([109.15217391]),
#  array([128.44797544]),
#  array([76.3997532]),
#  array([86.372573]),
#  array([83.03850376]),
#  array([125.46033628]),
#  array([12.16432084]),
#  array([78.24730709]),
#  array([195.11103968]),
#  array([98.03476598]),
#  array([66.69397573]),
#  array([63.58299328]),
#  array([78.30475696]),
#  array([55.823702]),
#  array([167.87378899]),
#  array([73.66026678]),
#  array([130.00507735]),
#  array([58.59576189]),
#  array([287.07935992]),
#  array([124.4798583]),
#  array([57.0559098]),
#  array([64.03484896]),
#  array([75.37830988]),
#  array([222.98824333]),
#  array([76.92167133]),
#  array([323.6646858]),
#  array([113.33319435]),
#  array([138.41963659]),
#  array([73.06373516]),
#  array([62.97927683]),
#  array([204.66021612]),
#  array([180.49492739]),
#  array([64.33361643]),
#  array([63.67907024]),
#  array([122.98644918]),
#  array([69.75419628]),
#  array([66.39249585]),
#  array([135.7516303]),
#  array([9.75415918]),
#  array([64.64402691]),
#  array([188.05679266]),
#  array([23.41423848]),
#  array([54.60152297]),
#  array([63.98292349]),
#  array([126.74799697]),
#  array([15.33150128]),
#  array([69.01977788]),
#  array([86.01109984]),
#  array([78.50927188]),
#  array([164.4030694]),
#  array([89.42911099]),
#  array([528.750061]),
#  array([63.58299328]),
#  array([60.1549008]),
#  array([62.51417594]),
#  array([71.33905016]),
#  array([110.30422063]),
#  array([71.31417277]),
#  array([72.73238804]),
#  array([125.11679259]),
#  array([16.02161906]),
#  array([74.88286871]),
#  array([161.16672154]),
#  array([64.45968583]),
#  array([467.36636638]),
#  array([75.98495918]),
#  array([136.18613674]),
#  array([85.18133947]),
#  array([71.86827663]),
#  array([498.75787188]),
#  array([5.27015994]),
#  array([87.24451208]),
#  array([84.14912031]),
#  array([76.0712792]),
#  array([71.17464178]),
#  array([55.19678022]),
#  array([93.67416975]),
#  array([196.18337444]),
#  array([192.89465414]),
#  array([96.827228]),
#  array([190.55398383]),
#  array([76.3796932]),
#  array([139.58242764]),
#  array([76.45025677]),
#  array([69.58167961]),
#  array([76.76609176]),
#  array([78.30475696]),
#  array([191.74064709]),
#  array([73.10570585]),
#  array([55.67642903]),
#  array([279.25039776]),
#  array([118.12785522]),
#  array([221.21829193]),
#  array([74.35372566]),
#  array([74.68279434]),
#  array([72.23394133]),
#  array([82.60311399]),
#  array([75.50205556]),
#  array([61.87597524]),
#  array([67.97367857]),
#  array([132.51738167]),
#  array([67.81588749]),
#  array([74.06377343]),
#  array([62.7675249]),
#  array([83.19725966]),
#  array([118.78853797]),
#  array([305.724346]),
#  array([136.91468771]),
#  array([65.20581554]),
#  array([228.00364741]),
#  array([205.3999901]),
#  array([85.08801507]),
#  array([118.93678223]),
#  array([75.48350802]),
#  array([119.9255157]),
#  array([84.9245963]),
#  array([81.77407781]),
#  array([213.60822644]),
#  array([69.74774053]),
#  array([123.12206829]),
#  array([30.40534185]),
#  array([64.27279914]),
#  array([10.71988255]),
#  array([62.86276868]),
#  array([62.4911156]),
#  array([356.10720194]),
#  array([192.83668236]),
#  array([82.35756227]),
#  array([81.41811712]),
#  array([63.48945016]),
#  array([88.92719718]),
#  array([166.62685717]),
#  array([66.47111595]),
#  array([71.36442358]),
#  array([65.43520957]),
#  array([86.19072028]),
#  array([62.78453661]),
#  array([68.89896037]),
#  array([67.90509712]),
#  array([68.06943721]),
#  array([62.65635371]),
#  array([71.10214215]),
#  array([113.56237619]),
#  array([81.66963875]),
#  array([78.24778169]),
#  array([74.12334009]),
#  array([67.93878597]),
#  array([75.87760093]),
#  array([257.11482167]),
#  array([74.61072937]),
#  array([132.4382878]),
#  array([75.46012639]),
#  array([55.28762468]),
#  array([228.34289145]),
#  array([71.8949839]),
#  array([74.31168198]),
#  array([68.31533005]),
#  array([79.37561574]),
#  array([61.40140783]),
#  array([67.36024701]),
#  array([113.61637879]),
#  array([77.72959352]),
#  array([75.70766566]),
#  array([54.33461184]),
#  array([256.03033676]),
#  array([105.46239893]),
#  array([85.40673306]),
#  array([57.51395504]),
#  array([234.56639363]),
#  array([90.20585416]),
#  array([76.65078181]),
#  array([111.6823015]),
#  array([78.58002731]),
#  array([146.42364677]),
#  array([190.69990639]),
#  array([72.5638977]),
#  array([177.68303001]),
#  array([120.65319645]),
#  array([115.34303712]),
#  array([78.1003033]),
#  array([105.66584355]),
#  array([108.62622573]),
#  array([193.88654305]),
#  array([224.70123834]),
#  array([115.87693948]),
#  array([118.50502355]),
#  array([164.23088051]),
#  array([115.50440985]),
#  array([168.28814489]),
#  array([81.73265886]),
#  array([58.76768103]),
#  array([63.35920083]),
#  array([81.54006613]),
#  array([119.20855781]),
#  array([63.11055845]),
#  array([88.01410467]),
#  array([75.31989113]),
#  array([58.32370973]),
#  array([181.9236076]),
#  array([79.83629146]),
#  array([260.95891675]),
#  array([62.85629365]),
#  array([121.42778538]),
#  array([172.11326161]),
#  array([66.17061695]),
#  array([140.68725134]),
#  array([78.3437412]),
#  array([118.9531873]),
#  array([67.69298452]),
#  array([32.85254572]),
#  array([75.63155773]),
#  array([130.87718699]),
#  array([78.27153566]),
#  array([66.21307193]),
#  array([73.06888921]),
#  array([166.51015364]),
#  array([86.91126929]),
#  array([139.6577377]),
#  array([450.92496997]),
#  array([60.71264292]),
#  array([75.21664067]),
#  array([55.93316185]),
#  array([61.0441824]),
#  array([191.0295532]),
#  array([116.27279828]),
#  array([125.10302676]),
#  array([52.0525512]),
#  array([74.61142684]),
#  array([85.95021232]),
#  array([88.56852724]),
#  array([163.60378617]),
#  array([83.67733325]),
#  array([75.56747553]),
#  array([133.71688827]),
#  array([67.6153573]),
#  array([199.10192374]),
#  array([118.38935958]),
#  array([242.53715247]),
#  array([137.55727675]),
#  array([83.85925274]),
#  array([71.81211272]),
#  array([136.18337295]),
#  array([80.37592979]),
#  array([274.93699613]),
#  array([74.20777994]),
#  array([72.04539684]),
#  array([86.12759247]),
#  array([70.54068952]),
#  array([22.6132367]),
#  array([229.68284335]),
#  array([93.52488953]),
#  array([64.18754131]),
#  array([81.36854937]),
#  array([80.25431057]),
#  array([103.35822642]),
#  array([81.74614788]),
#  array([125.41410931]),
#  array([74.15376998]),
#  array([69.86045593]),
#  array([47.21470975]),
#  array([123.76166075]),
#  array([132.94749707]),
#  array([69.08923058]),
#  array([123.93575549]),
#  array([110.70105662]),
#  array([141.54741756]),
#  array([144.65971894]),
#  array([78.05422324]),
#  array([72.27019876]),
#  array([138.19537399]),
#  ...]

# %%
list(ytest["price"])
# Out:
# [265.0,
#  175.0,
#  185.0,
#  36.0,
#  26.0,
#  52.0,
#  335.0,
#  139.0,
#  142.0,
#  78.0,
#  38.0,
#  39.0,
#  30.0,
#  75.0,
#  47.39,
#  115.0,
#  180.0,
#  82.0,
#  57.0,
#  80.0,
#  69.0,
#  48.5,
#  465.0,
#  33.0,
#  70.0,
#  550.0,
#  70.25,
#  46.0,
#  115.0,
#  249.0,
#  59.0,
#  30.0,
#  60.0,
#  239.0,
#  135.0,
#  81.0,
#  46.13,
#  35.0,
#  93.0,
#  48.0,
#  15.0,
#  72.54,
#  88.0,
#  58.0,
#  150.0,
#  54.79,
#  175.0,
#  60.0,
#  50.0,
#  56.12,
#  160.0,
#  360.0,
#  118.0,
#  95.0,
#  344.0,
#  175.0,
#  75.0,
#  43.09,
#  65.0,
#  45.0,
#  43.0,
#  46.0,
#  240.0,
#  145.0,
#  95.0,
#  75.0,
#  63.0,
#  240.0,
#  44.0,
#  180.0,
#  40.0,
#  40.08,
#  95.0,
#  550.0,
#  25.0,
#  44.0,
#  85.0,
#  400.0,
#  30.0,
#  240.0,
#  105.0,
#  78.57,
#  65.0,
#  58.0,
#  62.0,
#  57.0,
#  45.0,
#  290.0,
#  95.0,
#  55.0,
#  44.5,
#  230.0,
#  32.0,
#  44.6,
#  81.0,
#  64.0,
#  48.0,
#  50.66,
#  55.0,
#  44.0,
#  175.0,
#  59.96,
#  35.0,
#  98.0,
#  44.0,
#  65.0,
#  48.45,
#  125.0,
#  60.0,
#  200.0,
#  43.5,
#  40.0,
#  230.0,
#  120.0,
#  75.0,
#  180.0,
#  85.0,
#  230.0,
#  125.0,
#  150.0,
#  73.0,
#  44.6,
#  25.88,
#  90.0,
#  55.0,
#  60.0,
#  25.0,
#  63.5,
#  46.8,
#  49.8,
#  68.0,
#  270.0,
#  46.0,
#  180.0,
#  86.0,
#  50.92,
#  235.0,
#  60.9,
#  212.0,
#  90.0,
#  57.0,
#  61.0,
#  60.0,
#  46.74,
#  47.39,
#  75.0,
#  245.0,
#  25.99,
#  115.0,
#  207.0,
#  220.0,
#  64.08,
#  170.0,
#  25.0,
#  300.0,
#  110.0,
#  105.0,
#  245.0,
#  47.0,
#  2912.0,
#  135.0,
#  85.0,
#  72.0,
#  175.0,
#  39.9,
#  58.0,
#  75.08,
#  32.92,
#  70.0,
#  42.0,
#  65.0,
#  65.0,
#  499.0,
#  79.0,
#  64.0,
#  84.0,
#  75.0,
#  57.95,
#  170.0,
#  105.0,
#  71.0,
#  95.0,
#  25.0,
#  45.0,
#  375.0,
#  49.0,
#  69.61,
#  38.36,
#  17.835,
#  56.0,
#  40.0,
#  52.0,
#  228.0,
#  100.0,
#  55.0,
#  50.0,
#  95.45,
#  140.0,
#  50.0,
#  51.77,
#  190.0,
#  76.0,
#  250.0,
#  51.89,
#  449.0,
#  63.0,
#  127.0,
#  250.0,
#  110.0,
#  105.0,
#  19.9,
#  43.0,
#  53.0,
#  35.88,
#  80.86,
#  100.0,
#  660.0,
#  72.5,
#  170.0,
#  112.0,
#  90.0,
#  72.0,
#  48.0,
#  45.0,
#  40.0,
#  140.0,
#  53.5,
#  33.0,
#  120.0,
#  63.0,
#  50.17,
#  93.0,
#  139.0,
#  800.0,
#  166.0,
#  74.0,
#  100.0,
#  85.0,
#  133.0,
#  63.0,
#  152.0,
#  55.0,
#  42.0,
#  42.0,
#  275.0,
#  42.41,
#  260.0,
#  65.0,
#  73.0,
#  40.0,
#  175.0,
#  110.0,
#  150.0,
#  88.0,
#  26.0,
#  52.0,
#  41.88,
#  100.0,
#  744.0,
#  69.09,
#  44.42,
#  37.6,
#  948.0,
#  65.0,
#  44.73,
#  28.18,
#  80.0,
#  99.0,
#  56.0,
#  150.0,
#  168.0,
#  53.0,
#  38.0,
#  228.5,
#  400.0,
#  315.0,
#  240.0,
#  39.0,
#  35.5,
#  95.0,
#  58.0,
#  26.0,
#  35.47,
#  75.0,
#  69.0,
#  500.0,
#  247.0,
#  115.0,
#  220.0,
#  63.0,
#  42.0,
#  52.82,
#  110.0,
#  350.0,
#  111.0,
#  49.0,
#  56.0,
#  76.0,
#  699.0,
#  55.0,
#  70.0,
#  70.0,
#  90.0,
#  60.0,
#  45.35,
#  100.0,
#  30.0,
#  119.0,
#  150.0,
#  230.0,
#  74.23,
#  42.0,
#  72.0,
#  65.0,
#  35.2,
#  117.0,
#  55.0,
#  135.0,
#  40.0,
#  56.55,
#  55.0,
#  51.0,
#  250.0,
#  57.0,
#  85.0,
#  16.0,
#  135.0,
#  95.0,
#  180.0,
#  420.0,
#  79.0,
#  70.0,
#  75.0,
#  54.8,
#  250.0,
#  140.0,
#  60.0,
#  1400.0,
#  82.0,
#  64.5,
#  108.0,
#  445.0,
#  118.0,
#  420.0,
#  76.3,
#  120.0,
#  35.0,
#  145.0,
#  43.0,
#  54.0,
#  102.0,
#  72.0,
#  450.0,
#  110.0,
#  68.0,
#  81.0,
#  150.0,
#  203.0,
#  49.36,
#  300.0,
#  55.0,
#  175.0,
#  47.0,
#  48.0,
#  95.0,
#  60.0,
#  67.4,
#  10.5,
#  275.0,
#  93.0,
#  52.04,
#  51.0,
#  55.0,
#  333.0,
#  75.0,
#  110.0,
#  101.0,
#  198.0,
#  51.0,
#  45.5,
#  47.0,
#  140.0,
#  52.5,
#  30.0,
#  40.0,
#  82.0,
#  60.0,
#  358.0,
#  64.8,
#  56.0,
#  42.85,
#  57.0,
#  40.45,
#  270.0,
#  943.0,
#  279.0,
#  24.0,
#  52.59,
#  68.0,
#  145.0,
#  325.0,
#  60.0,
#  61.3,
#  200.0,
#  56.0,
#  32.0,
#  50.0,
#  50.0,
#  49.11,
#  260.0,
#  90.0,
#  89.0,
#  130.0,
#  170.0,
#  114.0,
#  170.0,
#  119.0,
#  50.0,
#  70.0,
#  245.0,
#  46.6,
#  36.8,
#  129.0,
#  66.0,
#  102.0,
#  54.4,
#  63.5,
#  67.0,
#  175.0,
#  34.0,
#  85.0,
#  523.0,
#  123.0,
#  50.0,
#  65.0,
#  58.0,
#  47.4,
#  50.0,
#  54.0,
#  82.0,
#  71.0,
#  78.0,
#  50.0,
#  52.0,
#  615.0,
#  27.0,
#  46.14,
#  45.0,
#  54.59,
#  1200.0,
#  140.0,
#  70.0,
#  108.0,
#  141.0,
#  70.0,
#  53.0,
#  125.0,
#  52.2,
#  36.29,
#  38.0,
#  53.0,
#  95.0,
#  75.0,
#  60.0,
#  170.0,
#  230.0,
#  85.0,
#  120.0,
#  88.5,
#  29.5,
#  197.0,
#  53.0,
#  130.0,
#  20.0,
#  75.0,
#  320.0,
#  45.5,
#  54.0,
#  245.0,
#  25.0,
#  43.0,
#  200.0,
#  38.5,
#  39.0,
#  34.0,
#  112.0,
#  123.0,
#  75.0,
#  50.4,
#  158.0,
#  47.74,
#  100.0,
#  90.0,
#  115.0,
#  16.45,
#  125.0,
#  130.0,
#  165.0,
#  65.0,
#  32.0,
#  115.0,
#  74.0,
#  57.39,
#  89.0,
#  24.0,
#  110.0,
#  139.0,
#  350.0,
#  165.0,
#  16.9,
#  32.9,
#  52.7,
#  1400.0,
#  31.95,
#  11.5,
#  53.0,
#  127.0,
#  75.0,
#  150.0,
#  54.0,
#  115.0,
#  61.0,
#  42.81,
#  63.0,
#  52.97,
#  100.0,
#  120.0,
#  140.0,
#  120.0,
#  85.0,
#  91.0,
#  29.46,
#  113.0,
#  42.0,
#  156.0,
#  68.4,
#  142.0,
#  75.0,
#  71.0,
#  45.0,
#  54.0,
#  53.0,
#  80.0,
#  37.5,
#  52.0,
#  45.0,
#  37.5,
#  59.0,
#  230.0,
#  70.0,
#  42.0,
#  49.9,
#  85.0,
#  30.0,
#  49.3,
#  300.0,
#  150.0,
#  90.0,
#  57.0,
#  74.0,
#  120.0,
#  160.0,
#  200.0,
#  33.65,
#  70.0,
#  215.0,
#  95.0,
#  95.0,
#  29.0,
#  89.0,
#  175.0,
#  43.0,
#  55.0,
#  45.0,
#  36.44,
#  27.98,
#  36.0,
#  101.0,
#  60.0,
#  120.0,
#  65.0,
#  73.0,
#  50.35,
#  60.0,
#  60.0,
#  150.0,
#  85.0,
#  91.0,
#  43.0,
#  240.0,
#  152.0,
#  111.0,
#  35.0,
#  66.0,
#  115.0,
#  85.0,
#  33.06,
#  65.21,
#  110.0,
#  80.0,
#  188.0,
#  210.0,
#  60.0,
#  41.0,
#  47.0,
#  58.0,
#  150.0,
#  320.0,
#  62.0,
#  33.84,
#  77.25,
#  65.0,
#  31.0,
#  559.0,
#  260.0,
#  415.0,
#  55.0,
#  32.0,
#  77.44,
#  80.99,
#  125.0,
#  35.0,
#  49.5,
#  58.0,
#  77.5,
#  150.0,
#  70.0,
#  28.0,
#  52.2,
#  85.0,
#  75.84,
#  121.0,
#  2200.0,
#  110.0,
#  329.0,
#  100.0,
#  60.0,
#  55.44,
#  250.0,
#  75.0,
#  393.5,
#  98.0,
#  75.5,
#  40.43,
#  166.0,
#  94.55,
#  75.0,
#  170.0,
#  135.0,
#  350.0,
#  70.0,
#  40.17,
#  31.0,
#  69.0,
#  47.405,
#  65.0,
#  48.0,
#  73.8,
#  60.0,
#  97.5,
#  35.14,
#  24.5,
#  180.0,
#  130.0,
#  49.87,
#  205.0,
#  55.0,
#  55.0,
#  85.0,
#  56.0,
#  51.1,
#  180.0,
#  74.5,
#  86.0,
#  395.0,
#  51.42,
#  65.0,
#  140.0,
#  75.0,
#  45.4,
#  300.0,
#  57.0,
#  65.0,
#  290.0,
#  326.0,
#  145.0,
#  46.0,
#  58.0,
#  40.0,
#  32.0,
#  50.79,
#  64.0,
#  150.0,
#  66.0,
#  40.0,
#  200.0,
#  125.0,
#  399.0,
#  218.0,
#  120.0,
#  59.0,
#  125.0,
#  325.0,
#  785.0,
#  200.0,
#  65.0,
#  864.0,
#  53.0,
#  60.0,
#  52.8,
#  72.0,
#  93.04,
#  32.25,
#  60.0,
#  57.0,
#  62.425,
#  40.14,
#  16.45,
#  113.0,
#  53.0,
#  200.0,
#  36.0,
#  34.18,
#  249.0,
#  44.0,
#  56.17,
#  125.0,
#  90.0,
#  54.0,
#  90.2,
#  70.0,
#  160.0,
#  60.0,
#  97.0,
#  125.0,
#  146.0,
#  17.535,
#  75.0,
#  420.0,
#  98.0,
#  57.0,
#  52.08,
#  84.0,
#  44.28,
#  100.0,
#  38.0,
#  155.0,
#  42.5,
#  215.0,
#  99.0,
#  46.0,
#  39.0,
#  75.0,
#  349.0,
#  38.0,
#  110.0,
#  72.0,
#  125.0,
#  75.0,
#  42.0,
#  250.0,
#  150.0,
#  45.0,
#  50.0,
#  150.0,
#  35.22,
#  37.0,
#  150.0,
#  13.57,
#  100.0,
#  140.0,
#  70.0,
#  45.0,
#  55.0,
#  146.0,
#  25.5,
#  42.88,
#  58.0,
#  87.0,
#  95.0,
#  75.0,
#  1700.0,
#  52.71,
#  55.0,
#  52.5,
#  50.0,
#  81.0,
#  59.0,
#  69.0,
#  180.0,
#  16.5,
#  58.25,
#  135.0,
#  42.0,
#  1200.0,
#  65.0,
#  162.0,
#  110.0,
#  62.0,
#  145.0,
#  13.0,
#  100.0,
#  75.0,
#  65.0,
#  47.0,
#  46.0,
#  110.0,
#  204.0,
#  400.0,
#  85.0,
#  300.0,
#  67.39,
#  360.0,
#  97.16,
#  65.0,
#  106.0,
#  79.0,
#  120.0,
#  75.0,
#  36.69,
#  250.0,
#  175.0,
#  245.0,
#  45.98,
#  52.0,
#  39.0,
#  43.71,
#  48.0,
#  59.0,
#  35.0,
#  56.0,
#  60.0,
#  32.49,
#  45.0,
#  75.97,
#  125.0,
#  425.0,
#  165.0,
#  67.0,
#  270.0,
#  95.0,
#  48.75,
#  268.0,
#  52.0,
#  91.86,
#  77.5,
#  78.0,
#  65.0,
#  86.26,
#  93.0,
#  18.5,
#  45.0,
#  70.0,
#  77.65,
#  53.11,
#  250.0,
#  368.0,
#  85.0,
#  110.0,
#  39.0,
#  64.5,
#  199.0,
#  40.8,
#  87.0,
#  62.0,
#  69.0,
#  26.5,
#  77.0,
#  36.75,
#  50.0,
#  68.0,
#  40.0,
#  103.0,
#  85.0,
#  42.0,
#  75.0,
#  58.0,
#  58.0,
#  190.0,
#  52.5,
#  95.0,
#  40.31,
#  55.0,
#  750.0,
#  55.0,
#  32.64,
#  80.0,
#  67.76,
#  38.0,
#  52.85,
#  85.73,
#  70.0,
#  71.5,
#  65.0,
#  140.0,
#  70.0,
#  40.0,
#  49.475,
#  157.0,
#  70.0,
#  63.0,
#  180.0,
#  63.0,
#  160.0,
#  100.0,
#  88.73,
#  205.0,
#  82.5,
#  95.0,
#  52.0,
#  65.0,
#  60.0,
#  250.0,
#  130.0,
#  65.0,
#  62.0,
#  190.0,
#  95.0,
#  120.0,
#  102.0,
#  40.0,
#  44.5,
#  61.5,
#  55.0,
#  33.0,
#  105.0,
#  52.0,
#  38.0,
#  105.0,
#  85.0,
#  200.0,
#  40.79,
#  118.0,
#  75.0,
#  51.0,
#  180.0,
#  41.58,
#  58.0,
#  40.43,
#  55.0,
#  51.0,
#  133.0,
#  57.0,
#  45.0,
#  47.88,
#  310.0,
#  60.0,
#  98.0,
#  225.0,
#  33.0,
#  68.0,
#  49.97,
#  48.0,
#  130.0,
#  93.0,
#  85.0,
#  45.0,
#  39.0,
#  67.73,
#  46.0,
#  195.0,
#  69.5,
#  80.0,
#  82.0,
#  45.75,
#  145.0,
#  57.23,
#  220.0,
#  205.0,
#  100.0,
#  27.0,
#  60.0,
#  99.39,
#  130.0,
#  32.49,
#  82.0,
#  115.0,
#  73.0,
#  34.1,
#  650.0,
#  55.0,
#  71.5,
#  90.0,
#  48.48,
#  73.5,
#  135.0,
#  135.0,
#  60.0,
#  200.0,
#  37.0,
#  71.89,
#  80.0,
#  69.0,
#  240.0,
#  70.0,
#  76.02,
#  125.0,
#  46.0,
#  77.0,
#  150.0,
#  ...]

# %%
from sklearn.metrics import mean_squared_error
import math
y_actual = list(ytest["price"])
y_predicted = predictions
 
MSE = mean_squared_error(y_actual, y_predicted)
 
RMSE = math.sqrt(MSE)
print("Root Mean Square Error:\n")
print(RMSE)
# Out:
# Root Mean Square Error:
#
# 112.17603138725364
